# %% [markdown]
# ## Import.io Technical Challenge-Ikea Chairs

# %%
# Requirement: Write a Python script that can download the results from the Details Extractor using the 
# Import.io API...
# To Dear Judgers:
#            Due to the reason that I need to pay for the "integrate" tab to get API call, I decide to download 
#            the file, import the CSV file, and perform the task. Otherwise, I might misunderstand the requirement. 
#            Either way, Sorry for not following the requirement. But I think nothing should stop me from solving the 
#            problem and finishing the task. 
#            
#            Thank you for your time and understanding! 
# Xiaoyue

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# import data
ikea = pd.read_csv("Details-Extractor-(Crawl-Run)---2019-01-03T041631Z.csv")
ikea.head(3)
# Out:
#                                                  url Article number  \
# 0  https://www.ikea.com/us/en/catalog/products/S8...     892.284.34
# 1  https://www.ikea.com/us/en/catalog/products/50...     503.322.38
# 2  https://www.ikea.com/us/en/catalog/products/60...     603.526.50
#
#   Product name Product price  \
# 0      ANTILOP        $22.99
# 1    RENBERGET        $49.99
# 2       LANGUR         $8.00
#
#                                              Tagline  \
# 0  High chair with tray, silver color white, silv...
# 1                        Swivel chair, Bomstad black
# 2           Padded seat cover for high chair, yellow
#
#                                    Short Description  \
# 0  ANTILOP high chair is easy to take apart and b...
# 1  Comfy and lightweight so it’s easy to move. Th...
# 2  The padded material relieves pressure on the c...
#
#                                        Product Image  \
# 0  https://www.ikea.com/us/en/images/products/ant...
# ...

# %%
type(ikea)
# Out:
# pandas.core.frame.DataFrame

# %%
ikea_P = ikea['Product price']

# %%
type(ikea_P)
# Out:
# pandas.core.series.Series

# %%
# check the column names. 
ikea.columns
# Out:
# Index(['url', 'Article number', 'Product name', 'Product price', 'Tagline',
#        'Short Description', 'Product Image', 'Product Image_alt'],
#       dtype='object')

# %%
# eliminate the space between names by .rename method. 
ikea.rename(columns= {"Article number" : "Article_number", 
                       "Product name" : "Product_name",
                      "Product price": "Product_price",
                      "Short Description": "Short_Description",
                      "Product Image" : "Product_Image",
                      "Product Image_alt" : "Product_Image_alt"}, inplace =True)
ikea.columns
# Out:
# Index(['url', 'Article_number', 'Product_name', 'Product_price', 'Tagline',
#        'Short_Description', 'Product_Image', 'Product_Image_alt'],
#       dtype='object')

# %%
# check data types. 
ikea.dtypes
# Out:
# url                  object
# Article_number       object
# Product_name         object
# Product_price        object
# Tagline              object
# Short_Description    object
# Product_Image        object
# Product_Image_alt    object
# dtype: object

# %%
# sort the data to have a overview. 
ikea_P = ikea_P.replace({'\$':''}, regex = True)
ikea_P.head()
# Out:
# 0     22.99
# 1     49.99
# 2      8.00
# 3     99.00
# 4    149.00
# Name: Product price, dtype: object

# %%
ikea_P = pd.to_numeric(ikea_P, errors='ignore')
ikea_P.head()
# Out:
# 0     22.99
# 1     49.99
# 2      8.00
# 3     99.00
# 4    149.00
# Name: Product price, dtype: object

# %%
ikea_P = pd.Series(ikea_P).convert_objects(convert_numeric=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.

# %%
ikea_P.sort_values(ascending= True)
# Out:
# 24      7.99
# 10      7.99
# 46      8.00
# 2       8.00
# 34     12.50
# 8      12.50
# 17     12.50
# 79     14.99
# 9      14.99
# 43     19.00
# 63     19.99
# 5      19.99
# 81     19.99
# 15     19.99
# 22     20.00
# 0      22.99
# 88     24.99
# 32     25.00
# 45     25.00
# 65     25.00
# 35     25.00
# 12     29.00
# 21     29.00
# 86     29.00
# 28     29.00
# 84     29.99
# 61     35.00
# 48     39.00
# 83     39.99
# 50     39.99
#        ...
# 56    109.00
# 7     109.00
# 82    119.00
# 36    129.00
# 57    139.00
# 64    147.00
# 4     149.00
# 58    149.00
# 39    169.00
# 42    169.00
# 23    169.00
# 14    169.00
# 33    169.00
# 52    189.00
# 18    199.00
# 73    199.00
# 66    219.00
# 26    249.00
# 55    249.00
# 68    269.00
# 13    279.00
# 51    329.00
# 37    349.00
# 92    499.00
# 87    585.00
# 69    593.00
# 94    599.00
# 93    699.00
# 95    849.00
# 53       NaN
# Name: Product price, Length: 96, dtype: float64

# %%
# removes chairs with a price less than $50
ikea_P[ikea_P > 50]
# Out:
# 3      99.00
# 4     149.00
# 6      79.00
# 7     109.00
# 13    279.00
# 14    169.00
# 16     79.99
# 18    199.00
# 19     59.99
# 23    169.00
# 25     89.00
# 26    249.00
# 29     99.00
# 30     79.00
# 31     79.00
# 33    169.00
# 36    129.00
# 37    349.00
# 39    169.00
# 40     99.00
# 41     99.99
# 42    169.00
# 44     69.99
# 47     69.00
# 49     69.00
# 51    329.00
# 52    189.00
# 54     69.00
# 55    249.00
# 56    109.00
# 57    139.00
# 58    149.00
# 59     59.99
# 62     69.99
# 64    147.00
# 66    219.00
# 68    269.00
# 69    593.00
# 73    199.00
# 74     75.00
# 76     59.99
# 80    109.00
# 82    119.00
# 85     60.00
# 87    585.00
# 91     79.99
# 92    499.00
# 93    699.00
# 94    599.00
# 95    849.00
# Name: Product price, dtype: float64

# %%
type(ikea_P[ikea_P > 50])
# Out:
# pandas.core.series.Series

# %%
# if the price is below $150, then the value should be Medium, otherwise it should be High.
def price_range(ikea_P):
    if ikea_P < 50:
        return ""
    elif ikea_P > 50 and ikea_P < 150:
        return "Medium"
    else:
        return "High"

# %%
ikea_P.apply(price_range)
# Out:
# 0
# 1
# 2
# 3     Medium
# 4     Medium
# 5
# 6     Medium
# 7     Medium
# 8
# 9
# 10
# 11
# 12
# 13      High
# 14      High
# 15
# 16    Medium
# 17
# 18      High
# 19    Medium
# 20
# 21
# 22
# 23      High
# 24
# 25    Medium
# 26      High
# 27
# 28
# 29    Medium
#        ...
# 66      High
# 67
# 68      High
# 69      High
# 70
# 71
# 72
# 73      High
# 74    Medium
# 75
# 76    Medium
# 77
# 78
# 79
# 80    Medium
# 81
# 82    Medium
# 83
# 84
# 85    Medium
# 86
# 87      High
# 88
# 89
# 90
# 91    Medium
# 92      High
# 93      High
# 94      High
# 95      High
# Name: Product price, Length: 96, dtype: object

# %%
# convert panda series to dataframe
df = pd.DataFrame({'':ikea_P.apply(price_range).index, 'price_range':ikea_P.apply(price_range).values})

# %%
ikea.append(df)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#          Article_number                                      Product_Image  \
# 0    NaN     892.284.34  https://www.ikea.com/us/en/images/products/ant...
# 1    NaN     503.322.38  https://www.ikea.com/us/en/images/products/ren...
# 2    NaN     603.526.50  https://www.ikea.com/us/en/images/products/lan...
# 3    NaN     591.977.78  https://www.ikea.com/us/en/images/products/poa...
# 4    NaN     004.025.68  https://www.ikea.com/us/en/images/products/eke...
# 5    NaN     790.462.60  https://www.ikea.com/us/en/images/products/sni...
# 6    NaN     603.347.22  https://www.ikea.com/us/en/images/products/tob...
# ...

# %% [raw]
# ikea.append(df).to_csv('out.csv')

# %%
ikea.merge(ikea_sub.to_frame(), left_on = "Product_price", right_index = True)
